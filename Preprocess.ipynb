# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(r"C:\Users\mpkhd\Desktop\Uni\4th year\Sem1\ST4052\Project1\recruitment_data.csv")

# %%
df.head()
# Out:
#    Age  Gender  EducationLevel  ExperienceYears  PreviousCompanies  \
# 0   26       1               2                0                  3
# 1   39       1               4               12                  3
# 2   48       0               2                3                  2
# 3   34       1               2                5                  2
# 4   30       0               1                6                  1
#
#    DistanceFromCompany  InterviewScore  SkillScore  PersonalityScore  \
# 0            26.783828              48          78                91
# 1            25.862694              35          68                80
# 2             9.920805              20          67                13
# 3             6.407751              36          27                70
# 4            43.105343              23          52                85
#
#    RecruitmentStrategy  HiringDecision
# 0                    1               1
# 1                    2               1
# 2                    2               0
# 3                    3               0
# 4                    2               0

# %%
#df.describe()
df.shape
# Out:
# (1500, 11)

# %%
df["HiringDecision"][(df["HiringDecision"] == 1)].count()
# Out:
# 465

# %%
colnames = df.columns
colnames.shape
# Out:
# (11,)

# %%
X = pd.DataFrame()
y = pd.DataFrame()

# %%
for i in colnames:
    if i != "HiringDecision":
        X[i] = df[i]
    else:
        y[i] = df[i]

# %%
X.head()
# Out:
#    Age  Gender  EducationLevel  ExperienceYears  PreviousCompanies  \
# 0   26       1               2                0                  3
# 1   39       1               4               12                  3
# 2   48       0               2                3                  2
# 3   34       1               2                5                  2
# 4   30       0               1                6                  1
#
#    DistanceFromCompany  InterviewScore  SkillScore  PersonalityScore  \
# 0            26.783828              48          78                91
# 1            25.862694              35          68                80
# 2             9.920805              20          67                13
# 3             6.407751              36          27                70
# 4            43.105343              23          52                85
#
#    RecruitmentStrategy
# 0                    1
# 1                    2
# 2                    2
# 3                    3
# 4                    2

# %%
y.head()
# Out:
#    HiringDecision
# 0               1
# 1               1
# 2               0
# 3               0
# 4               0

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %%
train = pd.concat([X_train,y_train],axis = 1)

# %%
test = pd.concat([X_test,y_test],axis = 1)

# %%
train.to_csv('my_file.csv', index=False)
